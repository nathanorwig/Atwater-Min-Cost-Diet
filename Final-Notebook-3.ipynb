# %% [markdown]
# # EEP 153: Project 2
# # Minimum Cost Diet: Vegans vs Vegetarians vs Omnivores
# ## By Keanna, Claire, Janice, Vincent and Youssef

# %% [markdown]
# ## Population of Interest

# %% [markdown]
# ### We are looking at different types of diets for people in the United States and comparing their minimum costs subject to nutritional constraints. The types of diets we will study are: Omnivorous, Vegetarian, and Vegan.

# %%
# import necessary packages
# !pip install -r requirements.txt
# !pip install wbdata

import ndb
import pandas as pd
import warnings
from  scipy.optimize import linprog as lp
import numpy as np
import wbdata
# Out:
# Requirement already satisfied: Pint>=0.8.1 in /srv/app/venv/lib/python3.6/site-packages (from -r requirements.txt (line 2))
# Requirement already satisfied: numpy>=1.15.0 in /srv/app/venv/lib/python3.6/site-packages (from -r requirements.txt (line 6))
# Requirement already satisfied: pandas>=0.23.3 in /srv/app/venv/lib/python3.6/site-packages (from -r requirements.txt (line 11))
# Requirement already satisfied: requests>=2.20.0 in /srv/app/venv/lib/python3.6/site-packages (from -r requirements.txt (line 15))
# Requirement already satisfied: scipy>=1.1.0 in /srv/app/venv/lib/python3.6/site-packages (from -r requirements.txt (line 18))
# Requirement already satisfied: python-dateutil>=2.5.0 in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.23.3->-r requirements.txt (line 11))
# Requirement already satisfied: pytz>=2011k in /srv/app/venv/lib/python3.6/site-packages (from pandas>=0.23.3->-r requirements.txt (line 11))
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /srv/app/venv/lib/python3.6/site-packages (from requests>=2.20.0->-r requirements.txt (line 15))
# Requirement already satisfied: idna<2.9,>=2.5 in /srv/app/venv/lib/python3.6/site-packages (from requests>=2.20.0->-r requirements.txt (line 15))
# Requirement already satisfied: certifi>=2017.4.17 in /srv/app/venv/lib/python3.6/site-packages (from requests>=2.20.0->-r requirements.txt (line 15))
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /srv/app/venv/lib/python3.6/site-packages (from requests>=2.20.0->-r requirements.txt (line 15))
# Requirement already satisfied: six>=1.5 in /srv/app/venv/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.23.3->-r requirements.txt (line 11))
# Requirement already satisfied: wbdata in /srv/app/venv/lib/python3.6/site-packages
# Requirement already satisfied: decorator in /srv/app/venv/lib/python3.6/site-packages (from wbdata)

# %% [markdown]
# ## Data on Food Prices

# %%
# import google spreadsheet with food prices for each of the 3 diets

# %%
omni_p = pd.read_csv('Data/omnivore food prices.csv', dtype=str)
vegi_p = pd.read_csv('Data/vegetarian food prices.csv', dtype=str)
veg_p = pd.read_csv('Data/vegan food prices.csv', dtype=str)

# %%
print(len(omni_p))
omni_p.head()
# Out:
# 85
#                                                 Food Quantity Units  Price  \
# 0      Flour, white, all purpose, per lb. (453.6 gm)        1    lb  0.439
# 1  Rice, white, long grain, uncooked, per lb. (45...        1    lb   0.73
# 2         Spaghetti and macaroni, per lb. (453.6 gm)        1    lb  1.217
# 3              Bread, white, pan, per lb. (453.6 gm)        1    lb  1.274
# 4        Bread, whole wheat, pan, per lb. (453.6 gm)        1    lb   1.94
#
#        Date Location       NDB
# 0  Jan 2019      DOL  45181883
# 1  Jan 2019      DOL  45285910
# 2  Jan 2019      DOL  45213192
# 3  Jan 2019      DOL     18069
# 4  Jan 2019      DOL     18075

# %%
print(len(vegi_p))
vegi_p.tail()
# Out:
# 58
#              Food Quantity Units Price      Date     Location       NDB
# 53     Navy Beans        1   lbs  1.49  Oct 2018       Target  45273292
# 54          Sugar        4   lbs  2.39  Oct 2018       Target     19336
# 55  Pancake Flour       32    oz  1.99  Oct 2018  Trader Joes  45054364
# 56          Beets        1   lbs  2.49  Oct 2018    Good Eggs     11080
# 57    Almond Milk       64    oz     3  Feb 2019      Safeway  45209232

# %%
print(len(veg_p))
veg_p.tail()
# Out:
# 51
#                  Food Quantity    Units Price      Date          Location  \
# 46          Olive Oil     25.4  Fl. Oz.  9.09  Feb 2019  Signature select
# 47           Avocados        4       ct  3.99  Feb 2019            Amazon
# 48               Tofu       14       oz  1.99  Feb 2019    Whole Food 365
# 49  Nutritional Yeast       10       oz  9.44  Feb 2019          NowFoods
# 50        Almond Milk       64       oz     3  Feb 2019           Safeway
#
#          NDB
# 46  45239582
# 47  45346458
# 48  45267096
# 49  45360902
# 50  45209232

# %% [markdown]
# ## Data on Nutritional Content

# %%
# join food price data with nutritional content data based on US recommendations

# %%
user = "casimirfunk"
apikey = {'casimirfunk':"inIyO1begWSRqsYtxS7m6p09PSyq7Qiw7fxzV2qN"}

# %%
D = {}
for food in  omni_p.Food.tolist():
    try:
        NDB = omni_p.loc[omni_p.Food==food,:].NDB
        D[food] = ndb.ndb_report(apikey[user],NDB).Quantity
    except AttributeError: 
        warnings.warn("Couldn't find NDB Code %s for food %s." % (food,NDB))
        

D = pd.DataFrame(D,dtype=float)

D
# Out:
#                                     Flour, white, all purpose, per lb. (453.6 gm)  \
# Caffeine                                                                      NaN
# Calcium, Ca                                                                67.000
# Carbohydrate, by difference                                                73.330
# Cholesterol                                                                 0.000
# Energy                                                                    367.000
# Fatty acids, total monounsaturated                                            NaN
# Fatty acids, total polyunsaturated                                            NaN
# Fatty acids, total saturated                                                0.000
# Fatty acids, total trans                                                    0.000
# Fiber, total dietary                                                        3.300
# Folate, DFE                                                                   NaN
# Iron, Fe                                                                    4.800
# Magnesium, Mg                                                                 NaN
# Niacin                                                                      5.333
# Phosphorus, P                                                                 NaN
# Potassium, K                                                                  NaN
# Protein                                                                    10.000
# Riboflavin                                                                  0.340
# Sodium, Na                                                                  0.000
# Sugars, total                                                               3.330
# Thiamin                                                                     0.000
# Total lipid (fat)                                                           0.000
# Vitamin A, IU                                                               0.000
# Vitamin A, RAE                                                                NaN
# Vitamin B-12                                                                  NaN
# Vitamin B-6                                                                   NaN
# Vitamin C, total ascorbic acid                                              0.000
# Vitamin D                                                                     NaN
# Vitamin D (D2 + D3)                                                           NaN
# Vitamin E (alpha-tocopherol)                                                  NaN
# Vitamin K (phylloquinone)                                                     NaN
# Water                                                                         NaN
# Zinc, Zn                                                                      NaN
#
#                                     Rice, white, long grain, uncooked, per lb. (453.6 gm)  \
# Caffeine                                                                          NaN
# Calcium, Ca                                                                    27.000
# Carbohydrate, by difference                                                    80.000
# Cholesterol                                                                     0.000
# Energy                                                                        356.000
# Fatty acids, total monounsaturated                                              0.000
# Fatty acids, total polyunsaturated                                              0.000
# Fatty acids, total saturated                                                    0.000
# Fatty acids, total trans                                                        0.000
# Fiber, total dietary                                                            2.200
# Folate, DFE                                                                   342.000
# Iron, Fe                                                                        4.440
# Magnesium, Mg                                                                  49.000
# Niacin                                                                          4.444
# Phosphorus, P                                                                     NaN
# Potassium, K                                                                  162.000
# Protein                                                                         8.890
# Riboflavin                                                                        NaN
# Sodium, Na                                                                      0.000
# Sugars, total                                                                   0.000
# Thiamin                                                                         0.000
# Total lipid (fat)                                                               0.000
# Vitamin A, IU                                                                     NaN
# Vitamin A, RAE                                                                    NaN
# Vitamin B-12                                                                      NaN
# Vitamin B-6                                                                       NaN
# Vitamin C, total ascorbic acid                                                    NaN
# Vitamin D                                                                       0.000
# Vitamin D (D2 + D3)                                                               NaN
# Vitamin E (alpha-tocopherol)                                                      NaN
# Vitamin K (phylloquinone)                                                         NaN
# Water                                                                             NaN
# Zinc, Zn                                                                          NaN
#
#                                     Spaghetti and macaroni, per lb. (453.6 gm)  \
# Caffeine                                                                   NaN
# Calcium, Ca                                                              0.000
# Carbohydrate, by difference                                             73.210
# Cholesterol                                                              0.000
# Energy                                                                 357.000
# Fatty acids, total monounsaturated                                       0.000
# Fatty acids, total polyunsaturated                                       0.890
# Fatty acids, total saturated                                             0.000
# Fatty acids, total trans                                                 0.000
# Fiber, total dietary                                                     3.600
# Folate, DFE                                                                NaN
# Iron, Fe                                                                 3.210
# Magnesium, Mg                                                              NaN
# Niacin                                                                   7.143
# Phosphorus, P                                                              NaN
# Potassium, K                                                               NaN
# Protein                                                                 12.500
# Riboflavin                                                               0.455
# Sodium, Na                                                                 NaN
# Sugars, total                                                            3.570
# Thiamin                                                                  1.000
# Total lipid (fat)                                                        1.790
# Vitamin A, IU                                                            0.000
# Vitamin A, RAE                                                             NaN
# Vitamin B-12                                                               NaN
# Vitamin B-6                                                                NaN
# Vitamin C, total ascorbic acid                                           0.000
# Vitamin D                                                                  NaN
# Vitamin D (D2 + D3)                                                        NaN
# Vitamin E (alpha-tocopherol)                                               NaN
# Vitamin K (phylloquinone)                                                  NaN
# Water                                                                      NaN
# Zinc, Zn                                                                   NaN
#
#                                     Bread, white, pan, per lb. (453.6 gm)  \
# Caffeine                                                            0.000
# Calcium, Ca                                                       144.000
# Carbohydrate, by difference                                        49.420
# Cholesterol                                                         0.000
# Energy                                                            266.000
# Fatty acids, total monounsaturated                                  0.599
# Fatty acids, total polyunsaturated                                  1.602
# Fatty acids, total saturated                                        0.698
# Fatty acids, total trans                                            0.027
# Fiber, total dietary                                                2.700
# Folate, DFE                                                       171.000
# Iron, Fe                                                            3.610
# Magnesium, Mg                                                      23.000
# Niacin                                                              4.780
# Phosphorus, P                                                      98.000
# Potassium, K                                                      126.000
# Protein                                                             8.850
# Riboflavin                                                          0.243
# Sodium, Na                                                        490.000
# Sugars, total                                                       5.670
# Thiamin                                                             0.533
# Total lipid (fat)                                                   3.330
# Vitamin A, IU                                                       1.000
# Vitamin A, RAE                                                      0.000
# Vitamin B-12                                                        0.000
# Vitamin B-6                                                         0.087
# Vitamin C, total ascorbic acid                                      0.000
# Vitamin D                                                           0.000
# Vitamin D (D2 + D3)                                                 0.000
# Vitamin E (alpha-tocopherol)                                        0.220
# Vitamin K (phylloquinone)                                           0.200
# Water                                                              36.420
# Zinc, Zn                                                            0.740
#
#                                     Bread, whole wheat, pan, per lb. (453.6 gm)  \
# Caffeine                                                                  0.000
# Calcium, Ca                                                             161.000
# Carbohydrate, by difference                                              42.710
# Cholesterol                                                               0.000
# Energy                                                                  252.000
# Fatty acids, total monounsaturated                                        0.620
# Fatty acids, total polyunsaturated                                        1.592
# Fatty acids, total saturated                                              0.722
# Fatty acids, total trans                                                  0.020
# Fiber, total dietary                                                      6.000
# Folate, DFE                                                              42.000
# Iron, Fe                                                                  2.470
# Magnesium, Mg                                                            75.000
# Niacin                                                                    4.438
# Phosphorus, P                                                           212.000
# Potassium, K                                                            254.000
# Protein                                                                  12.450
# Riboflavin                                                                0.167
# Sodium, Na                                                              455.000
# Sugars, total                                                             4.340
# Thiamin                                                                   0.394
# Total lipid (fat)                                                         3.500
# Vitamin A, IU                                                             3.000
# Vitamin A, RAE                                                            0.000
# Vitamin B-12                                                              0.000
# Vitamin B-6                                                               0.215
# Vitamin C, total ascorbic acid                                            0.000
# Vitamin D                                                                 0.000
# Vitamin D (D2 + D3)                                                       0.000
# Vitamin E (alpha-tocopherol)                                              2.660
# Vitamin K (phylloquinone)                                                 7.800
# Water                                                                    39.010
# Zinc, Zn                                                                  1.770
#
#                                     Cookies, chocolate chip, per lb. (453.6 gm)  \
# Caffeine                                                                 12.000
# Calcium, Ca                                                              43.000
# Carbohydrate, by difference                                              66.100
# Cholesterol                                                               0.000
# Energy                                                                  497.000
# Fatty acids, total monounsaturated                                       13.077
# Fatty acids, total polyunsaturated                                        2.620
# Fatty acids, total saturated                                              8.316
# Fatty acids, total trans                                                    NaN
# Fiber, total dietary                                                        NaN
# Folate, DFE                                                              83.000
# Iron, Fe                                                                  2.070
# Magnesium, Mg                                                            36.000
# Niacin                                                                    1.990
# Phosphorus, P                                                            80.000
# Potassium, K                                                            208.000
# Protein                                                                   4.600
# Riboflavin                                                                0.205
# Sodium, Na                                                              290.000
# Sugars, total                                                               NaN
# Thiamin                                                                   0.195
# Total lipid (fat)                                                        25.200
# Vitamin A, IU                                                             4.000
# Vitamin A, RAE                                                            0.000
# Vitamin B-12                                                              0.000
# Vitamin B-6                                                               0.017
# Vitamin C, total ascorbic acid                                            0.000
# Vitamin D                                                                   NaN
# Vitamin D (D2 + D3)                                                         NaN
# Vitamin E (alpha-tocopherol)                                                NaN
# Vitamin K (phylloquinone)                                                   NaN
# Water                                                                     3.000
# Zinc, Zn                                                                  0.600
#
#                                     Ground chuck, 100% beef, per lb. (453.6 gm)  \
# Caffeine                                                                    NaN
# Calcium, Ca                                                              18.000
# Carbohydrate, by difference                                               0.000
# Cholesterol                                                              71.000
# Energy                                                                  250.000
# Fatty acids, total monounsaturated                                          NaN
# Fatty acids, total polyunsaturated                                          NaN
# Fatty acids, total saturated                                              8.040
# Fatty acids, total trans                                                    NaN
# Fiber, total dietary                                                        NaN
# Folate, DFE                                                                 NaN
# Iron, Fe                                                                  1.610
# Magnesium, Mg                                                            14.000
# Niacin                                                                    4.464
# Phosphorus, P                                                           179.000
# Potassium, K                                                                NaN
# Protein                                                                  16.960
# Riboflavin                                                                0.152
# Sodium, Na                                                               67.000
# Sugars, total                                                               NaN
# Thiamin                                                                   0.000
# Total lipid (fat)                                                        19.640
# Vitamin A, IU                                                               NaN
# Vitamin A, RAE                                                              NaN
# Vitamin B-12                                                              2.140
# Vitamin B-6                                                               0.357
# Vitamin C, total ascorbic acid                                              NaN
# Vitamin D                                                                   NaN
# Vitamin D (D2 + D3)                                                         NaN
# Vitamin E (alpha-tocopherol)                                                NaN
# Vitamin K (phylloquinone)                                                   NaN
# Water                                                                       NaN
# Zinc, Zn                                                                  4.020
#
#                                     Ground beef, 100% beef, per lb. (453.6 gm)  \
# Caffeine                                                                   NaN
# Calcium, Ca                                                               0.00
# Carbohydrate, by difference                                               0.00
# Cholesterol                                                              62.00
# Energy                                                                  205.00
# Fatty acids, total monounsaturated                                         NaN
# Fatty acids, total polyunsaturated                                         NaN
# Fatty acids, total saturated                                              6.25
# Fatty acids, total trans                                                  0.00
# Fiber, total dietary                                                      0.00
# Folate, DFE                                                                NaN
# Iron, Fe                                                                  1.61
# Magnesium, Mg                                                              NaN
# Niacin                                                                     NaN
# Phosphorus, P                                                              NaN
# Potassium, K                                                               NaN
# Protein                                                                  18.75
# Riboflavin                                                                 NaN
# Sodium, Na                                                               67.00
# Sugars, total                                                             0.00
# Thiamin                                                                    NaN
# Total lipid (fat)                                                        15.18
# Vitamin A, IU                                                             0.00
# Vitamin A, RAE                                                             NaN
# Vitamin B-12                                                               NaN
# Vitamin B-6                                                                NaN
# Vitamin C, total ascorbic acid                                            0.00
# Vitamin D                                                                  NaN
# Vitamin D (D2 + D3)                                                        NaN
# Vitamin E (alpha-tocopherol)                                               NaN
# Vitamin K (phylloquinone)                                                  NaN
# Water                                                                      NaN
# Zinc, Zn                                                                   NaN
#
#                                     Ground beef, lean and extra lean, per lb. (453.6 gm)  \
# Caffeine                                                                          NaN
# Calcium, Ca                                                                      0.00
# Carbohydrate, by difference                                                      0.00
# Cholesterol                                                                     54.00
# Energy                                                                         125.00
# Fatty acids, total monounsaturated                                                NaN
# Fatty acids, total polyunsaturated                                                NaN
# Fatty acids, total saturated                                                     1.79
# Fatty acids, total trans                                                         0.00
# Fiber, total dietary                                                             0.00
# Folate, DFE                                                                       NaN
# Iron, Fe                                                                         2.41
# Magnesium, Mg                                                                     NaN
# Niacin                                                                            NaN
# Phosphorus, P                                                                     NaN
# Potassium, K                                                                      NaN
# Protein                                                                         21.43
# Riboflavin                                                                        NaN
# Sodium, Na                                                                      62.00
# Sugars, total                                                                    0.00
# Thiamin                                                                           NaN
# Total lipid (fat)                                                                4.02
# Vitamin A, IU                                                                    0.00
# Vitamin A, RAE                                                                    NaN
# Vitamin B-12                                                                      NaN
# Vitamin B-6                                                                       NaN
# Vitamin C, total ascorbic acid                                                   0.00
# Vitamin D                                                                         NaN
# Vitamin D (D2 + D3)                                                               NaN
# Vitamin E (alpha-tocopherol)                                                      NaN
# Vitamin K (phylloquinone)                                                         NaN
# Water                                                                             NaN
# Zinc, Zn                                                                          NaN
#
#                                     All uncooked ground beef, per lb. (453.6 gm)  \
# Caffeine                                                                     NaN
# Calcium, Ca                                                                  NaN
# Carbohydrate, by difference                                                 0.00
# Cholesterol                                                                71.00
# Energy                                                                    250.00
# Fatty acids, total monounsaturated                                           NaN
# Fatty acids, total polyunsaturated                                           NaN
# Fatty acids, total saturated                                                8.04
# Fatty acids, total trans                                                     NaN
# Fiber, total dietary                                                         NaN
# Folate, DFE                                                                  NaN
# Iron, Fe                                                                    1.61
# Magnesium, Mg                                                                NaN
# Niacin                                                                       NaN
# Phosphorus, P                                                                NaN
# Potassium, K                                                                 NaN
# Protein                                                                    16.96
# Riboflavin                                                                   NaN
# Sodium, Na                                                                 67.00
# Sugars, total                                                                NaN
# Thiamin                                                                      NaN
# Total lipid (fat)                                                          19.64
# Vitamin A, IU                                                                NaN
# Vitamin A, RAE                                                               NaN
# Vitamin B-12                                                                 NaN
# Vitamin B-6                                                                  NaN
# Vitamin C, total ascorbic acid                                               NaN
# Vitamin D                                                                    NaN
# Vitamin D (D2 + D3)                                                          NaN
# Vitamin E (alpha-tocopherol)                                                 NaN
# Vitamin K (phylloquinone)                                                    NaN
# Water                                                                        NaN
# Zinc, Zn                                                                     NaN
#
#                                        ...          Peas  Chickpeas  Almonds  \
# Caffeine                               ...         0.000        NaN    0.000
# Calcium, Ca                            ...        25.000      31.00  269.000
# Carbohydrate, by difference            ...        14.450      15.38   21.550
# Cholesterol                            ...         0.000       0.00    0.000
# Energy                                 ...        81.000      92.00  579.000
# Fatty acids, total monounsaturated     ...         0.035        NaN   31.551
# Fatty acids, total polyunsaturated     ...         0.187        NaN   12.329
# Fatty acids, total saturated           ...         0.071       0.00    3.802
# Fatty acids, total trans               ...         0.000       0.00    0.015
# Fiber, total dietary                   ...         5.700       3.10   12.500
# Folate, DFE                            ...        65.000        NaN   44.000
# Iron, Fe                               ...         1.470       1.08    3.710
# Magnesium, Mg                          ...        33.000        NaN  270.000
# Niacin                                 ...         2.090        NaN    3.618
# Phosphorus, P                          ...       108.000        NaN  481.000
# Potassium, K                           ...       244.000     177.00  733.000
# Protein                                ...         5.420       4.62   21.150
# Riboflavin                             ...         0.132        NaN    1.138
# Sodium, Na                             ...         5.000     246.00    1.000
# Sugars, total                          ...         5.670       0.77    4.350
# Thiamin                                ...         0.266        NaN    0.205
# Total lipid (fat)                      ...         0.400       1.54   49.930
# Vitamin A, IU                          ...       765.000        NaN    2.000
# Vitamin A, RAE                         ...        38.000        NaN    0.000
# Vitamin B-12                           ...         0.000        NaN    0.000
# Vitamin B-6                            ...         0.169        NaN    0.137
# Vitamin C, total ascorbic acid         ...        40.000        NaN    0.000
# Vitamin D                              ...         0.000       0.00    0.000
# Vitamin D (D2 + D3)                    ...         0.000        NaN    0.000
# Vitamin E (alpha-tocopherol)           ...         0.130        NaN   25.630
# Vitamin K (phylloquinone)              ...        24.800        NaN    0.000
# Water                                  ...        78.860        NaN    4.410
# Zinc, Zn                               ...         1.240        NaN    3.120
#
#                                       Chia  Olive Oil  Avocados    Tofu  \
# Caffeine                               NaN        NaN       NaN     NaN
# Calcium, Ca                         633.00        NaN      0.00   76.00
# Carbohydrate, by difference          41.67       0.00     10.00    2.53
# Cholesterol                           0.00       0.00      0.00    0.00
# Energy                              500.00     800.00    167.00  101.00
# Fatty acids, total monounsaturated    0.00      66.67       NaN     NaN
# Fatty acids, total polyunsaturated   25.00       6.67       NaN     NaN
# Fatty acids, total saturated          0.00      13.33      1.67    0.63
# Fatty acids, total trans              0.00       0.00      0.00    0.00
# Fiber, total dietary                 33.30        NaN      6.70    1.30
# Folate, DFE                            NaN        NaN       NaN     NaN
# Iron, Fe                              8.33        NaN      1.20    1.37
# Magnesium, Mg                          NaN        NaN       NaN     NaN
# Niacin                                 NaN        NaN       NaN     NaN
# Phosphorus, P                          NaN        NaN       NaN     NaN
# Potassium, K                          0.00        NaN       NaN  316.00
# Protein                              16.67       0.00      0.00   10.13
# Riboflavin                             NaN        NaN       NaN     NaN
# Sodium, Na                            0.00       0.00    400.00   19.00
# Sugars, total                         0.00        NaN      3.33    0.00
# Thiamin                                NaN        NaN       NaN     NaN
# Total lipid (fat)                    29.17      86.67     15.00    5.06
# Vitamin A, IU                          NaN        NaN       NaN    0.00
# Vitamin A, RAE                         NaN        NaN       NaN     NaN
# Vitamin B-12                           NaN        NaN       NaN     NaN
# Vitamin B-6                            NaN        NaN       NaN     NaN
# Vitamin C, total ascorbic acid         NaN        NaN       NaN    0.00
# Vitamin D                             0.00        NaN    133.00     NaN
# Vitamin D (D2 + D3)                    NaN        NaN       NaN     NaN
# Vitamin E (alpha-tocopherol)           NaN        NaN       NaN     NaN
# Vitamin K (phylloquinone)              NaN        NaN       NaN     NaN
# Water                                  NaN        NaN       NaN     NaN
# Zinc, Zn                               NaN        NaN       NaN     NaN
#
#                                     Nutritional Yeast  Yoghurt  Almond Milk
# Caffeine                                          NaN      NaN          NaN
# Calcium, Ca                                    40.000   189.00       185.00
# Carbohydrate, by difference                    33.330     5.73         0.62
# Cholesterol                                     0.000    22.00         0.00
# Energy                                        400.000   106.00        12.00
# Fatty acids, total monounsaturated                NaN      NaN          NaN
# Fatty acids, total polyunsaturated                NaN      NaN          NaN
# Fatty acids, total saturated                    0.000     3.96         0.00
# Fatty acids, total trans                        0.000     0.00         0.00
# Fiber, total dietary                           20.000     0.00         0.30
# Folate, DFE                                       NaN      NaN          NaN
# Iron, Fe                                        6.670     0.24         0.33
# Magnesium, Mg                                     NaN      NaN         7.00
# Niacin                                        306.667      NaN          NaN
# Phosphorus, P                                     NaN      NaN        12.00
# Potassium, K                                 1760.000      NaN        74.00
# Protein                                        53.330     7.49         0.31
# Riboflavin                                     64.667      NaN          NaN
# Sodium, Na                                    167.000    70.00        74.00
# Sugars, total                                   0.000     5.73         0.00
# Thiamin                                        79.000      NaN          NaN
# Total lipid (fat)                               3.330     6.17         1.08
# Vitamin A, IU                                     NaN   198.00       231.00
# Vitamin A, RAE                                    NaN      NaN          NaN
# Vitamin B-12                                  117.330      NaN          NaN
# Vitamin B-6                                    39.333      NaN          NaN
# Vitamin C, total ascorbic acid                    NaN     0.00         0.00
# Vitamin D                                       0.000      NaN        43.00
# Vitamin D (D2 + D3)                               NaN      NaN          NaN
# Vitamin E (alpha-tocopherol)                      NaN      NaN          NaN
# Vitamin K (phylloquinone)                         NaN      NaN          NaN
# Water                                             NaN      NaN          NaN
# Zinc, Zn                                          NaN      NaN          NaN
#
# [33 rows x 85 columns]

# %%
# Convert price and quantity values into floats from strings
for df in [omni_p, vegi_p, veg_p]:
    df['Price'] = df['Price'].astype(float)
    df['Quantity'] = df['Quantity'].astype(float)

# %%
# Convert food quantities to NDB units
veg_p['NDB Quantity'] = veg_p[['Quantity','Units']].T.apply(lambda x : ndb.ndb_units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
veg_p['NDB Price'] = veg_p['Price']/veg_p['NDB Quantity']

veg_p.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
veg_prices = veg_p.groupby('Food')['NDB Price'].min()

veg_prices.head()
# Out:
# Food
# Almond Milk                    0.16534669663865817 / hectogram
# Almonds                         2.2094327075691726 / hectogram
# Apples Red Delicious Large      0.5048585804033696 / hectogram
# Asparagus Green                 0.8796444261176615 / hectogram
# Avocados                      0.009975000000000001 / hectogram
# Name: NDB Price, dtype: object

# %%
# Choose sex/age group:
group = "F 19-30"

# Define *minimums*
bmin = pd.read_csv('./diet_minimums.csv').set_index('Nutrition')[group]

# Define *maximums*
bmax = pd.read_csv('./diet_maximums.csv').set_index('Nutrition')[group]

# %% [markdown]
# ## Minimum Cost Solutions

# %%
# solve for minimum cost diets for omnivores

# Convert food quantities to NDB units
omni_p['NDB Quantity'] = omni_p[['Quantity','Units']].T.apply(lambda x : ndb.ndb_units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
omni_p['NDB Price'] = omni_p['Price']/omni_p['NDB Quantity']

omni_p.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
omni_prices = omni_p.groupby('Food')['NDB Price'].min()

# %%
# solve for minimum cost diets for omnivores

tol = 1e-2 # Numbers in solution smaller than this (in absolute value) treated as zeros

c = omni_prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = list(set(c.index.tolist()).intersection(D.columns.tolist()))
c = c[use]

# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[c.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Minimum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([-Amin,Amax])

b = pd.concat([-bmin,bmax]) # Note sign change for min constraints

# Now solve problem!
result = lp(c, A, b, method='interior-point')

# Put back into nice series
diet = pd.Series(result.x,index=c.index)

print("Cost of diet for %s is $%4.2f per day." % (group,result.fun))
print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.

tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b)})
print("\nWith the following nutritional outcomes of interest:")
print(tab)

print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
# Out:
# Cost of diet for F 19-30 is $2.26 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# Food
# Avocados                                                 3.853701
# Rice, white, long grain, uncooked, per lb. (453.6 gm)    0.352921
# Liver (Pork)                                             0.823036
# Bananas, per lb. (453.6 gm)                              2.330894
# Milk (Whole)                                             2.082329
# Almonds                                                  0.543212
# Cabbage                                                  1.122871
# Beans, dried, any type, all sizes, per lb. (453.6 gm)    0.480319
# dtype: float64
#
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          2400.000000          2000.0
# Protein                           65.859456            46.0
# Fiber, total dietary              65.725404            28.0
# Folate, DFE                      400.000000           400.0
# Calcium, Ca                     1000.000000          1000.0
# Carbohydrate, by difference      313.799370           130.0
# Iron, Fe                          34.072629            18.0
# Magnesium, Mg                    443.986047           310.0
# Niacin                            23.955291            14.0
# Phosphorus, P                    700.000001           700.0
# Potassium, K                    4700.000001          4700.0
# Riboflavin                         3.914830             1.1
# Thiamin                            1.100000             1.1
# Vitamin A, RAE                  5384.962516           700.0
# Vitamin B-12                      21.796461             2.4
# Vitamin B-6                        1.940411             1.3
# Vitamin C, total ascorbic acid    78.236147            75.0
# Vitamin E (alpha-tocopherol)      15.000000            15.0
# Vitamin K (phylloquinone)         90.000000            90.0
# Zinc, Zn                           8.059468             8.0
# Vitamin D                        600.000000           600.0
# Sodium, Na                      1759.285250          2300.0
# Energy                          2400.000000          2400.0
#
# Constraining nutrients are:
# ['Folate, DFE', 'Calcium, Ca', 'Phosphorus, P', 'Potassium, K', 'Thiamin', 'Vitamin E (alpha-tocopherol)', 'Vitamin K (phylloquinone)', 'Vitamin D', 'Energy']

# %%
# solve for vegetarians

# Convert food quantities to NDB units
vegi_p['NDB Quantity'] = vegi_p[['Quantity','Units']].T.apply(lambda x : ndb.ndb_units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
vegi_p['NDB Price'] = vegi_p['Price']/vegi_p['NDB Quantity']

vegi_p.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
vegi_prices = vegi_p.groupby('Food')['NDB Price'].min()

# %%
# solve for minimum cost diets for vegetarians

tol = 1e-2 # Numbers in solution smaller than this (in absolute value) treated as zeros

c = vegi_prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = list(set(c.index.tolist()).intersection(D.columns.tolist()))
c = c[use]

# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[c.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Minimum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([-Amin,Amax])

b = pd.concat([-bmin,bmax]) # Note sign change for min constraints

# Now solve problem!
result = lp(c, A, b, method='interior-point')

# Put back into nice series
diet = pd.Series(result.x,index=c.index)

print("Cost of diet for %s is $%4.2f per day." % (group,result.fun))
print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.

tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b)})
print("\nWith the following nutritional outcomes of interest:")
print(tab)

print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
# Out:
# Cost of diet for F 19-30 is $3.48 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# Food
# Almond Milk                                              0.358236
# Avocados                                                 4.395457
# Bananas, per lb. (453.6 gm)                              1.710185
# Almonds                                                  0.337327
# Lentils                                                  1.108161
# Cabbage                                                  0.481098
# Nutritional Yeast                                        0.020455
# Spinach                                                  1.438925
# Beans, dried, any type, all sizes, per lb. (453.6 gm)    0.473858
# Bread, whole wheat, pan, per lb. (453.6 gm)              0.808709
# dtype: float64
#
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          2400.000000          2000.0
# Protein                           72.876240            46.0
# Fiber, total dietary              78.493812            28.0
# Folate, DFE                      903.398400           400.0
# Calcium, Ca                     1000.000000          1000.0
# Carbohydrate, by difference      325.335705           130.0
# Iron, Fe                          25.496414            18.0
# Magnesium, Mg                    510.470777           310.0
# Niacin                            19.912045            14.0
# Phosphorus, P                    858.961938           700.0
# Potassium, K                    4700.000000          4700.0
# Riboflavin                         2.777171             1.1
# Thiamin                            3.420579             1.1
# Vitamin A, RAE                   700.000000           700.0
# Vitamin B-12                       2.400000             2.4
# Vitamin B-6                        2.715782             1.3
# Vitamin C, total ascorbic acid    75.000000            75.0
# Vitamin E (alpha-tocopherol)      15.000000            15.0
# Vitamin K (phylloquinone)        746.689580            90.0
# Zinc, Zn                           8.000000             8.0
# Vitamin D                        600.000000           600.0
# Sodium, Na                      2300.000000          2300.0
# Energy                          2400.000000          2400.0
#
# Constraining nutrients are:
# ['Calcium, Ca', 'Potassium, K', 'Vitamin A, RAE', 'Vitamin B-12', 'Vitamin C, total ascorbic acid', 'Vitamin E (alpha-tocopherol)', 'Zinc, Zn', 'Vitamin D', 'Sodium, Na', 'Energy']

# %%
# solve for vegans

# Convert food quantities to NDB units
veg_p['NDB Quantity'] = veg_p[['Quantity','Units']].T.apply(lambda x : ndb.ndb_units(x['Quantity'],x['Units']))

# Now may want to filter df by time or place--need to get a unique set of food names.
veg_p['NDB Price'] = veg_p['Price']/veg_p['NDB Quantity']

veg_p.dropna(how='any') # Drop food with any missing data

# To use minimum price observed
veg_prices = veg_p.groupby('Food')['NDB Price'].min()

# %%
# solve for minimum cost diets for vegans

tol = 1e-2 # Numbers in solution smaller than this (in absolute value) treated as zeros

c = veg_prices.apply(lambda x:x.magnitude).dropna()

# Compile list that we have both prices and nutritional info for; drop if either missing
use = list(set(c.index.tolist()).intersection(D.columns.tolist()))
c = c[use]

# Drop nutritional information for foods we don't know the price of,
# and replace missing nutrients with zeros.
Aall = D[c.index].fillna(0)

# Drop rows of A that we don't have constraints for.
Amin = Aall.loc[bmin.index]

Amax = Aall.loc[bmax.index]

# Minimum requirements involve multiplying constraint by -1 to make <=.
A = pd.concat([-Amin,Amax])

b = pd.concat([-bmin,bmax]) # Note sign change for min constraints

# Now solve problem!
result = lp(c, A, b, method='interior-point')

# Put back into nice series
diet = pd.Series(result.x,index=c.index)

print("Cost of diet for %s is $%4.2f per day." % (group,result.fun))
print("\nYou'll be eating (in 100s of grams or milliliters):")
print(diet[diet >= tol])  # Drop items with quantities less than precision of calculation.

tab = pd.DataFrame({"Outcome":np.abs(A).dot(diet),"Recommendation":np.abs(b)})
print("\nWith the following nutritional outcomes of interest:")
print(tab)

print("\nConstraining nutrients are:")
excess = tab.diff(axis=1).iloc[:,1]
print(excess.loc[np.abs(excess) < tol].index.tolist())
# Out:
# Cost of diet for F 19-30 is $3.48 per day.
#
# You'll be eating (in 100s of grams or milliliters):
# Food
# Almond Milk                                              0.358236
# Avocados                                                 4.395457
# Bananas, per lb. (453.6 gm)                              1.710185
# Almonds                                                  0.337327
# Lentils                                                  1.108161
# Cabbage                                                  0.481098
# Nutritional Yeast                                        0.020455
# Spinach                                                  1.438925
# Beans, dried, any type, all sizes, per lb. (453.6 gm)    0.473858
# Bread, whole wheat, pan, per lb. (453.6 gm)              0.808709
# dtype: float64
#
# With the following nutritional outcomes of interest:
#                                     Outcome  Recommendation
# Nutrition
# Energy                          2399.999999          2000.0
# Protein                           72.876240            46.0
# Fiber, total dietary              78.493812            28.0
# Folate, DFE                      903.398409           400.0
# Calcium, Ca                     1000.000002          1000.0
# Carbohydrate, by difference      325.335706           130.0
# Iron, Fe                          25.496414            18.0
# Magnesium, Mg                    510.470776           310.0
# Niacin                            19.912045            14.0
# Phosphorus, P                    858.961937           700.0
# Potassium, K                    4700.000020          4700.0
# Riboflavin                         2.777171             1.1
# Thiamin                            3.420579             1.1
# Vitamin A, RAE                   700.000001           700.0
# Vitamin B-12                       2.400000             2.4
# Vitamin B-6                        2.715782             1.3
# Vitamin C, total ascorbic acid    75.000001            75.0
# Vitamin E (alpha-tocopherol)      15.000000            15.0
# Vitamin K (phylloquinone)        746.689570            90.0
# Zinc, Zn                           8.000000             8.0
# Vitamin D                        600.000001           600.0
# Sodium, Na                      2299.999961          2300.0
# Energy                          2399.999999          2400.0
#
# Constraining nutrients are:
# ['Calcium, Ca', 'Potassium, K', 'Vitamin A, RAE', 'Vitamin B-12', 'Vitamin C, total ascorbic acid', 'Vitamin E (alpha-tocopherol)', 'Zinc, Zn', 'Vitamin D', 'Sodium, Na', 'Energy']

# %% [markdown]
# ## Recipes

# %% [markdown]
# ## 3 Dishes using ingredients for each type of minimum cost diet
# ### Omnivore: California Liver Roll or Pig Liver Congee
# ### Vegetarian/Vegan: Spicy Lentil Mash w/ Whole Wheat Bread
#
# #### Both: Avocado Cabbage Salad
# #### Snacks: Bananas, Almonds

# %% [markdown]
# ### Notes: any additional ingredients needed (add to cost)
# * Salt (4 cents per oz)
# * Pepper (82 cents per oz)
# * Curry powder (86 cents per oz)

# %% [markdown]
# ## Total Cost for Population

# %%
# compute total cost and quantity to feed certain population with mix of age/sex groups (can use population project data)

# %%
# Get age/sex counts for the United States in 2017
# get list of all possible countries and years
age_range_codes = []
# Ranges are in 5 year sets up to 80
for i in range(0,80,5):
    age_range_codes.append(f"{i:02d}"+f"{i+4:02d}")
age_range_codes.append("80UP")

variable_labels ={"SP.POP.TOTL":"Population, total"}
total_pop_df = wbdata.get_dataframe(variable_labels) 
total_pop_df = total_pop_df.dropna().reset_index()[["country", "date"]]
total_pop_df["date"] = total_pop_df["date"].astype(int)
total_pop_df["country_code"] = total_pop_df["country"].apply(lambda row: wbdata.search_countries(row, display = False)[0]['id'])


def inner_pop(year, age_code, place, people):  
    if people == 'females':
        gender = 'FE'
    if people == 'males':
        gender = 'MA'
    
    data = 'SP.POP' + '.' + age_code + '.' + gender
    
    variable_labels = {data :"Population"}
        
    if place == 'world':
        place_code = 'WLD' # fixes bug where search also returns arab world
    else:
        place_code = wbdata.search_countries(place, display = False)[0]['id'] # finds country code for place listed
    
    try: 
        df = wbdata.get_dataframe(variable_labels, country=[place_code]) 
    except:
        print('Error: The place you listed may not be in the World Bank database or resulted in multiple possible countries or regions. Call wbdata.search_countries(place) to see the possible options and then refine your place query accordingly.')
    
    df.index = df.index.astype(int)
    
    population = df.loc[year, :][0]
    
    return int(population)


def population_df(regions = "all", years = "all"):
    
    pop_df = total_pop_df
    if type(regions) != list and regions != "all":
        regions = [regions]
    region_codes = []
    for region in regions:
        region_codes.append(wbdata.search_countries(region, display = False)[0]['id'])
    if type(years) != list and years != "all":
        years = [years]
    if regions == "all" and years == "all":
        for age in age_range_codes:
            pop_df[age + 'MA'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'males'), axis = 1)
            pop_df[age + 'FE'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'females'), axis = 1)
    elif regions == "all" and years != "all":
        pop_df = pop_df[pop_df['date'].isin(years)].reset_index(drop=True)
        for year in years:
            for age in age_range_codes:
                pop_df[age + 'MA'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'males'), axis = 1)
                pop_df[age + 'FE'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'females'), axis = 1)
    elif years == "all" and regions != "all":
        pop_df = pop_df[pop_df['country_code'].isin(region_codes)].reset_index(drop=True)
        for region in regions:
            for age in age_range_codes:
                pop_df[age + 'MA'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'males'), axis = 1)
                pop_df[age + 'FE'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'females'), axis = 1)
    else:
        pop_df = pop_df[(pop_df['date'].isin(years))&(pop_df['country_code'].isin(region_codes))].reset_index(drop=True)
        for region in regions:
            for year in years:
                for age in age_range_codes:
                    pop_df[age + 'MA'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'males'), axis = 1)
                    pop_df[age + 'FE'] = pop_df.apply(lambda row: inner_pop(row["date"], age, row["country"], 'females'), axis = 1)
    pop_df['country'] = pop_df['country'].str.lower()
    pop_df.set_index(['country', 'date'], inplace=True)
    pop_df.drop(columns = ['country_code'], inplace = True)
    return pop_df
usa = population_df(['united states'], [2017])
usa
# Out:
#                       0004MA   0004FE    0509MA    0509FE    1014MA    1014FE  \
# country       date
# united states 2017  10123826  9676632  10624312  10158892  10740556  10279316
#
#                       1519MA    1519FE    2024MA    2024FE   ...      6064MA  \
# country       date                                           ...
# united states 2017  10853401  10423372  11661144  11177860   ...     9601635
#
#                       6064FE   6569MA   6569FE   7074MA   7074FE   7579MA  \
# country       date
# united states 2017  10238782  7939154  8810296  5728630  6741741  3868301
#
#                      7579FE   80UPMA   80UPFE
# country       date
# united states 2017  4753069  4825690  7537631
#
# [1 rows x 34 columns]

# %%
# assume uniform distribution of ages within age range to establish new age ranges to fit nutritional data
ages = {}
keys = ['C 1-3', 'F 4-8', 'M 4-8', 'F 9-13', 'M 9-13', 'F 14-18', 'M 14-18', 'F 19-30', 'M 19-30', 'F 31-50', 'M 31-50', 'F 51+', 'M 51+']

# 1-3
ages[keys[0]] = 3/4 * usa.iloc[0, 0] + 3/4 * usa.iloc[0, 1]
# 4-8
ages[keys[1]] = 1/4 * usa.iloc[0, 1] + 3/4* usa.iloc[0, 3]
ages[keys[2]] = 1/4 * usa.iloc[0, 0] + 3/4* usa.iloc[0, 2]
# 9-13
ages[keys[3]] = 1/4 * usa.iloc[0, 3] + 3/4* usa.iloc[0, 5]
ages[keys[4]] = 1/4 * usa.iloc[0, 2] + 3/4* usa.iloc[0, 4]
# 14-18
ages[keys[5]] = 1/4 * usa.iloc[0, 5] + 3/4* usa.iloc[0, 7]
ages[keys[6]] = 1/4 * usa.iloc[0, 4] + 3/4* usa.iloc[0, 6]
# 19-30
ages[keys[7]] = 1/4 * usa.iloc[0, 7] + usa.iloc[0, 9] + usa.iloc[0, 11] + 1/4 * usa.iloc[0, 13]
ages[keys[8]] = 1/4 * usa.iloc[0, 6] + usa.iloc[0, 8] + usa.iloc[0, 10] + 1/4 * usa.iloc[0, 12]
# 31-50
ages[keys[9]] = 1/4 * usa.iloc[0, 13] + usa.iloc[0, 15] + usa.iloc[0, 17] + usa.iloc[0, 19]
ages[keys[10]] = 1/4 * usa.iloc[0, 12] + usa.iloc[0, 14] + usa.iloc[0, 16] + usa.iloc[0, 18]
# 51+
ages[keys[11]] = 3/4 * usa.iloc[0, 21] + usa.iloc[0, 23] + usa.iloc[0, 25] + usa.iloc[0, 27] + usa.iloc[0, 29] + usa.iloc[0, 31] + usa.iloc[0, 33]
ages[keys[12]] = 3/4 * usa.iloc[0, 20] + usa.iloc[0, 22] + usa.iloc[0, 24] + usa.iloc[0, 26] + usa.iloc[0, 28] + usa.iloc[0, 30] + usa.iloc[0, 32]

ages
# Out:
# {'C 1-3': 14850343.5,
#  'F 4-8': 10038327.0,
#  'M 4-8': 10499190.5,
#  'F 9-13': 10249210.0,
#  'M 9-13': 10711495.0,
#  'F 14-18': 10387358.0,
#  'M 14-18': 10825189.75,
#  'F 19-30': 27862129.5,
#  'M 19-30': 28984147.25,
#  'F 31-50': 33305728.5,
#  'M 31-50': 33395588.0,
#  'F 51+': 57263372.5,
#  'M 51+': 50923636.25}

# %%
# loop through sex/age groups:
n = 0
costs = np.array([0] * 39)
costs = costs.astype(float)
for diet_prices in [omni_prices, vegi_prices, veg_prices]:
    for group in list(ages.keys()):
        # Define *minimums*
        bmin = pd.read_csv('./diet_minimums.csv').set_index('Nutrition')[group]

        # Define *maximums*
        bmax = pd.read_csv('./diet_maximums.csv').set_index('Nutrition')[group]


        # solve for minimum cost diet

        tol = 1e-2 # Numbers in solution smaller than this (in absolute value) treated as zeros

        c = diet_prices.apply(lambda x:x.magnitude).dropna()

        # Compile list that we have both prices and nutritional info for; drop if either missing
        use = list(set(c.index.tolist()).intersection(D.columns.tolist()))
        c = c[use]

        # Drop nutritional information for foods we don't know the price of,
        # and replace missing nutrients with zeros.
        Aall = D[c.index].fillna(0)

        # Drop rows of A that we don't have constraints for.
        Amin = Aall.loc[bmin.index]

        Amax = Aall.loc[bmax.index]

        # Minimum requirements involve multiplying constraint by -1 to make <=.
        A = pd.concat([-Amin,Amax])

        b = pd.concat([-bmin,bmax]) # Note sign change for min constraints

        # Now solve problem!
        result = lp(c, A, b, method='interior-point')
        costs[n] = result.fun 
        n = n+1
        # Put back into nice series
        diet = pd.Series(result.x,index=c.index)
        
        print("Cost of diet for %s is $%4.2f per day." % (group,result.fun))
# Out:
# Cost of diet for C 1-3 is $1.31 per day.
# Cost of diet for F 4-8 is $1.60 per day.
# Cost of diet for M 4-8 is $1.50 per day.
# Cost of diet for F 9-13 is $2.63 per day.
# Cost of diet for M 9-13 is $2.52 per day.
# Cost of diet for F 14-18 is $2.84 per day.
# Cost of diet for M 14-18 is $2.75 per day.
# Cost of diet for F 19-30 is $2.26 per day.
# Cost of diet for M 19-30 is $2.32 per day.
# Cost of diet for F 31-50 is $2.32 per day.
# Cost of diet for M 31-50 is $2.35 per day.
# Cost of diet for F 51+ is $2.92 per day.
# Cost of diet for M 51+ is $2.35 per day.
# Cost of diet for C 1-3 is $2.41 per day.
# Cost of diet for F 4-8 is $2.47 per day.
# Cost of diet for M 4-8 is $2.33 per day.
# Cost of diet for F 9-13 is $4.08 per day.
# Cost of diet for M 9-13 is $3.74 per day.
# Cost of diet for F 14-18 is $4.27 per day.
# Cost of diet for M 14-18 is $4.50 per day.
# Cost of diet for F 19-30 is $3.48 per day.
# Cost of diet for M 19-30 is $4.15 per day.
# Cost of diet for F 31-50 is $3.62 per day.
# Cost of diet for M 31-50 is $4.27 per day.
# Cost of diet for F 51+ is $4.27 per day.
# Cost of diet for M 51+ is $4.27 per day.
# Cost of diet for C 1-3 is $2.41 per day.
# Cost of diet for F 4-8 is $2.47 per day.
# Cost of diet for M 4-8 is $2.33 per day.
# Cost of diet for F 9-13 is $4.25 per day.
# Cost of diet for M 9-13 is $3.97 per day.
# Cost of diet for F 14-18 is $4.38 per day.
# Cost of diet for M 14-18 is $4.54 per day.
# Cost of diet for F 19-30 is $3.48 per day.
# Cost of diet for M 19-30 is $4.15 per day.
# Cost of diet for F 31-50 is $3.62 per day.
# Cost of diet for M 31-50 is $4.27 per day.
# Cost of diet for F 51+ is $4.27 per day.
# Cost of diet for M 51+ is $4.27 per day.

# %%
df = pd.DataFrame({'Omnivores': costs[0:13], 'Vegetarians': costs[13:26], 'Vegans': costs[26:39]})
df.index = list(ages.keys())
df['USA Population in 2017'] = list(ages.values())
df
# Out:
#          Omnivores  Vegetarians    Vegans  USA Population in 2017
# C 1-3     1.307326     2.409688  2.409688             14850343.50
# F 4-8     1.603603     2.467128  2.467128             10038327.00
# M 4-8     1.499916     2.328522  2.328521             10499190.50
# F 9-13    2.629885     4.077082  4.246407             10249210.00
# M 9-13    2.517160     3.740784  3.971882             10711495.00
# F 14-18   2.840988     4.265007  4.382013             10387358.00
# M 14-18   2.750629     4.496713  4.540923             10825189.75
# F 19-30   2.260096     3.479948  3.479948             27862129.50
# M 19-30   2.322775     4.147369  4.147343             28984147.25
# F 31-50   2.320168     3.619675  3.619675             33305728.50
# M 31-50   2.347217     4.267438  4.267438             33395588.00
# F 51+     2.916437     4.269859  4.269866             57263372.50
# M 51+     2.347213     4.267453  4.267438             50923636.25

# %%
# most expensive diet: Male Vegans between 14-18
print('Cost per day:', df['Vegans']['M 14-18'])
# Out:
# Cost per day: 4.54092313600337

# %%
omni_cost = 0
for n in list(range(12)):
    omni_cost += df.iloc[n, 0] * df.iloc[n, 3]
print('Total Cost of Minimum Cost Omnivore Diet for U.S. Population in 2017:', '${:,.2f}'.format(omni_cost))
print('Average Cost of Minimum Cost Omnivore Diet for U.S. Population in 2017:', '${:,.2f}'.format(omni_cost / sum(df.iloc[:, 3])))
# Out:
# Total Cost of Minimum Cost Omnivore Diet for U.S. Population in 2017: $617,424,192.71
# Average Cost of Minimum Cost Omnivore Diet for U.S. Population in 2017: $2.00

# %%
vegi_cost = 0
for n in list(range(12)):
    vegi_cost += df.iloc[n, 1] * df.iloc[n, 3]
print('Total Cost of Minimum Cost Vegetarian Diet for U.S. Population in 2017:', '${:,.2f}'.format(vegi_cost))
print('Average Cost of Minimum Cost Vegetarian Diet for U.S. Population in 2017:', '${:,.2f}'.format(vegi_cost / sum(df.iloc[:, 3])))
# Out:
# Total Cost of Minimum Cost Vegetarian Diet for U.S. Population in 2017: $984,577,121.23
# Average Cost of Minimum Cost Vegetarian Diet for U.S. Population in 2017: $3.18

# %%
veg_cost = 0
for n in list(range(12)):
    veg_cost += df.iloc[n, 2] * df.iloc[n, 3]
print('Total Cost of Minimum Cost Vegan Diet for U.S. Population in 2017:', '${:,.2f}'.format(veg_cost))
print('Average Cost of Minimum Cost Vegan Diet for U.S. Population in 2017:', '${:,.2f}'.format(veg_cost / sum(df.iloc[:, 3])))
# Out:
# Total Cost of Minimum Cost Vegan Diet for U.S. Population in 2017: $990,481,541.51
# Average Cost of Minimum Cost Vegan Diet for U.S. Population in 2017: $3.20

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### See presentation.
